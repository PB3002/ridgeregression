# %%
import pandas as pd

# %%
weather = pd.read_csv("local_weather.csv",index_col ="DATE")

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2023-06-27  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2023-06-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2023-06-29  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2023-06-30  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2023-07-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
#              AWND  DAPR  FMTM  FRGT  MDPR  PGTM  ...  WT01  WT02  WT03  WT04  \
# DATE                                             ...
# 1960-01-01    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-02    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-03    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-04    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-05    NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# ...           ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...
# 2023-06-27  10.51   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2023-06-28  10.74   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2023-06-29   9.17   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2023-06-30   9.17   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2023-07-01   6.26   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
#
#             WT05  WT07  WT08  WT09  WT16  WT18
# DATE
# 1960-01-01   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-02   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-03   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-04   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-05   NaN   NaN   1.0   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...
# 2023-06-27   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-06-28   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-06-29   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-06-30   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-07-01   NaN   NaN   NaN   NaN   NaN   NaN
#
# [17379 rows x 35 columns]

# %%
weather.loc["1960-01-01":"1960-01-31",:]
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-06  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-07  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-08  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-09  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-10  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-11  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-12  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-13  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-14  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-15  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-16  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-17  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-18  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-19  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-20  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-21  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-22  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-23  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-24  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-25  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-26  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-27  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-29  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-30  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-31  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
#             AWND  DAPR  FMTM  FRGT  MDPR  PGTM  ...  WT01  WT02  WT03  WT04  \
# DATE                                            ...
# 1960-01-01   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-02   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-03   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-04   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-05   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-06   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-07   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-08   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-09   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-10   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-11   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-12   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-13   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-14   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-15   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-16   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-17   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-18   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-19   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-20   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-21   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-22   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-23   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-24   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-25   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-26   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-27   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-28   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-29   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-30   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 1960-01-31   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
#
#             WT05  WT07  WT08  WT09  WT16  WT18
# DATE
# 1960-01-01   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-02   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-03   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-04   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-05   NaN   NaN   1.0   NaN   NaN   NaN
# 1960-01-06   NaN   NaN   1.0   NaN   NaN   NaN
# 1960-01-07   NaN   NaN   1.0   NaN   1.0   NaN
# 1960-01-08   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-09   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-10   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-11   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-12   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-13   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-14   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-15   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-16   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-17   NaN   NaN   1.0   NaN   NaN   NaN
# 1960-01-18   NaN   NaN   1.0   NaN   1.0   NaN
# 1960-01-19   NaN   NaN   1.0   NaN   NaN   NaN
# 1960-01-20   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-21   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-22   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-23   NaN   NaN   1.0   NaN   NaN   NaN
# 1960-01-24   NaN   NaN   1.0   NaN   1.0   NaN
# 1960-01-25   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-26   NaN   NaN   NaN   NaN   1.0   NaN
# 1960-01-27   NaN   NaN   NaN   NaN   NaN   NaN
# 1960-01-28   NaN   NaN   1.0   NaN   NaN   NaN
# 1960-01-29   NaN   NaN   1.0   NaN   1.0   NaN
# 1960-01-30   NaN   NaN   1.0   NaN   1.0   NaN
# 1960-01-31   NaN   NaN   1.0   NaN   1.0   NaN
#
# [31 rows x 35 columns]

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.663732
# ACSH       0.663732
# AWND       0.506761
# DAPR       0.999540
# FMTM       0.873986
# FRGT       0.999885
# MDPR       0.999540
# PGTM       0.510213
# PRCP       0.016226
# SNOW       0.345187
# SNWD       0.338052
# TAVG       0.882790
# TMAX       0.000633
# TMIN       0.000806
# TSUN       0.933771
# WDF1       0.663732
# WDF2       0.506703
# WDF5       0.511767
# WDFG       0.754474
# WSF1       0.663732
# WSF2       0.506646
# WSF5       0.511767
# WSFG       0.754474
# WT01       0.778123
# WT02       0.980264
# WT03       0.992520
# WT04       0.999770
# WT05       0.998331
# WT07       0.999885
# WT08       0.813856
# WT09       0.999885
# WT16       0.887508
# WT18       0.999827
# dtype: float64

# %%
core_weather = weather[["PRCP","SNOW","SNWD","TMAX","TMIN"]].copy()

# %%
core_weather.columns=["precip","snow","snow_depth","temp_max","temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01     0.0   0.0         0.0      49.0      30.0
# 1960-01-02     0.0   0.0         0.0      49.0      29.0
# 1960-01-03     0.0   0.0         0.0      54.0      35.0
# 1960-01-04     0.0   0.0         0.0      54.0      36.0
# 1960-01-05     0.0   0.0         0.0      55.0      33.0
# ...            ...   ...         ...       ...       ...
# 2023-06-27     0.0   NaN         NaN      63.0      53.0
# 2023-06-28     0.0   NaN         NaN      64.0      53.0
# 2023-06-29     0.0   NaN         NaN      71.0      54.0
# 2023-06-30     0.0   NaN         NaN      73.0      53.0
# 2023-07-01     0.0   NaN         NaN      87.0      54.0
#
# [17379 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip         282
# snow          5999
# snow_depth    5875
# temp_max        11
# temp_min        14
# dtype: int64

# %%
core_weather["snow"].value_counts()
# Out:
# 0.0    11379
# 1.0        1
# Name: snow, dtype: int64

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 0.0    11504
# Name: snow_depth, dtype: int64

# %%
del core_weather["snow"]

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-12     NaN      63.0      55.0
# 1983-11-13     NaN      60.0      50.0
# ...            ...       ...       ...
# 2016-05-01     NaN      80.0      55.0
# 2016-05-02     NaN      68.0      53.0
# 2016-05-08     NaN      67.0      56.0
# 2017-10-28     NaN      68.0      50.0
# 2023-03-29     NaN      52.0      43.0
#
# [282 rows x 3 columns]

# %%
core_weather.loc["2013-12-15",:]
# Out:
# precip       NaN
# temp_max    58.0
# temp_min    33.0
# Name: 2013-12-15, dtype: float64

# %%
core_weather["precip"].value_counts() / core_weather.shape[0]
# Out:
# 0.00    0.811439
# 0.01    0.025491
# 0.02    0.011623
# 0.03    0.007135
# 0.04    0.006042
#           ...
# 1.05    0.000058
# 1.38    0.000058
# 1.95    0.000058
# 2.01    0.000058
# 1.28    0.000058
# Name: precip, Length: 179, dtype: float64

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip       0
# temp_max    11
# temp_min    14
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     0.0       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN
# 2022-10-08     0.0       NaN       NaN
# 2022-10-09     0.0       NaN       NaN
# 2022-10-10     0.0      69.0       NaN
# 2022-10-11     0.0      66.0       NaN

# %%
core_weather.loc["2011-12-18":"2011-12-28"]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2011-12-18     0.0      52.0      33.0
# 2011-12-19     0.0      55.0      35.0
# 2011-12-20     0.0      61.0      35.0
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2011-12-26     0.0      50.0      32.0
# 2011-12-27     0.0      56.0      39.0
# 2011-12-28     0.0      57.0      38.0

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.apply(lambda x: (x == 9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04', '1960-01-05',
#        '1960-01-06', '1960-01-07', '1960-01-08', '1960-01-09', '1960-01-10',
#        ...
#        '2023-06-22', '2023-06-23', '2023-06-24', '2023-06-25', '2023-06-26',
#        '2023-06-27', '2023-06-28', '2023-06-29', '2023-06-30', '2023-07-01'],
#       dtype='object', name='DATE', length=17379)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2023-06-22', '2023-06-23', '2023-06-24', '2023-06-25',
#                '2023-06-26', '2023-06-27', '2023-06-28', '2023-06-29',
#                '2023-06-30', '2023-07-01'],
#               dtype='datetime64[ns]', name='DATE', length=17379, freq=None)

# %%
core_weather.index.year
# Out:
# Int64Index([1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960,
#             ...
#             2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
#            dtype='int64', name='DATE', length=17379)

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 1960    366
# 1961    365
# 1962    365
# 1963    365
# 1964    366
# 1965    365
# 1966    365
# 1967    365
# 1968    366
# 1969    365
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1983    184
# 1984    366
# 1985    365
# 1986    212
# 2000    365
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    365
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    182
# Name: DATE, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).apply(lambda x: x["precip"].sum()).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01     0.0      49.0      30.0    49.0
# 1960-01-02     0.0      49.0      29.0    54.0
# 1960-01-03     0.0      54.0      35.0    54.0
# 1960-01-04     0.0      54.0      36.0    55.0
# 1960-01-05     0.0      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2023-06-27     0.0      63.0      53.0    64.0
# 2023-06-28     0.0      64.0      53.0    71.0
# 2023-06-29     0.0      71.0      54.0    73.0
# 2023-06-30     0.0      73.0      53.0    87.0
# 2023-07-01     0.0      87.0      54.0     NaN
#
# [17379 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01     0.0      49.0      30.0    49.0
# 1960-01-02     0.0      49.0      29.0    54.0
# 1960-01-03     0.0      54.0      35.0    54.0
# 1960-01-04     0.0      54.0      36.0    55.0
# 1960-01-05     0.0      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2023-06-26     0.0      63.0      54.0    63.0
# 2023-06-27     0.0      63.0      53.0    64.0
# 2023-06-28     0.0      64.0      53.0    71.0
# 2023-06-29     0.0      71.0      54.0    73.0
# 2023-06-30     0.0      73.0      53.0    87.0
#
# [17378 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2020-12-31"]
test = core_weather.loc["2021-01-01":]

# %%
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01    0.00      49.0      30.0    49.0
# 1960-01-02    0.00      49.0      29.0    54.0
# 1960-01-03    0.00      54.0      35.0    54.0
# 1960-01-04    0.00      54.0      36.0    55.0
# 1960-01-05    0.00      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2020-12-27    0.00      63.0      44.0    61.0
# 2020-12-28    0.10      61.0      42.0    60.0
# 2020-12-29    0.00      60.0      39.0    56.0
# 2020-12-30    0.07      56.0      36.0    62.0
# 2020-12-31    0.06      62.0      44.0    60.0
#
# [16467 rows x 4 columns]

# %%
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2021-01-01    0.00      60.0      40.0    57.0
# 2021-01-02    0.14      57.0      51.0    56.0
# 2021-01-03    0.00      56.0      49.0    62.0
# 2021-01-04    0.36      62.0      46.0    59.0
# 2021-01-05    0.00      59.0      42.0    59.0
# ...            ...       ...       ...     ...
# 2023-06-26    0.00      63.0      54.0    63.0
# 2023-06-27    0.00      63.0      53.0    64.0
# 2023-06-28    0.00      64.0      53.0    71.0
# 2023-06-29    0.00      71.0      54.0    73.0
# 2023-06-30    0.00      73.0      53.0    87.0
#
# [911 rows x 4 columns]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(test["target"], predictions)
# Out:
# 19.6273825528659

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    59.806024
# 2021-01-02    56.0    59.310181
# 2021-01-03    62.0    58.538685
# 2021-01-04    59.0    61.531814
# 2021-01-05    59.0    59.444266
# ...            ...          ...
# 2023-06-26    63.0    64.485105
# 2023-06-27    64.0    64.305415
# 2023-06-28    71.0    65.026553
# 2023-06-29    73.0    70.254212
# 2023-06-30    87.0    71.516798
#
# [911 rows x 2 columns]

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-2.20730384,  0.72113834,  0.17969047])

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean())
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year).apply(lambda x: x.expanding(1).mean())

# %%
error, combined = create_predictions(predictors + ["monthly_avg", "day_of_year_avg"], core_weather, reg)
error
# Out:
# 18.47825985829703

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.204248
# temp_max           0.822036
# temp_min           0.596027
# target             1.000000
# month_max          0.687595
# month_day_max     -0.421078
# max_min            0.044844
# monthly_avg        0.690329
# day_of_year_avg    0.712023
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2022-06-20    98.0    76.721867  21.278133
# 2022-05-23    86.0    69.676120  16.323880
# 2023-06-30    87.0    71.911513  15.088487
# 2021-01-17    83.0    68.433744  14.566256
# 2022-09-03    91.0    76.576690  14.423310
# 2021-04-01    62.0    75.713379  13.713379
# 2021-05-07    81.0    67.678091  13.321909
# 2022-03-21    78.0    64.772237  13.227763
# 2023-05-12    80.0    67.081323  12.918677
# 2021-02-21    77.0    64.141065  12.858935
